# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\hp\OneDrive\Desktop\pydata1\CALIFONIA HOUSING CSV\california_housing_test.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data.shape
# Out:
# (3000, 9)

# %%
data.nunique()
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# population            1802
# households            1026
# median_income         2578
# median_house_value    1784
# dtype: int64

# %%
data.value_counts()
# Out:
# longitude  latitude  housing_median_age  total_rooms  total_bedrooms  population  households  median_income  median_house_value
# -114.49    33.97     17.0                2809.0       635.0           83.0        45.0        1.6154         87500.0               1
# -124.18    40.79     40.0                1398.0       311.0           788.0       279.0       1.4668         64600.0               1
# -124.17    41.80     16.0                2739.0       480.0           1259.0      436.0       3.7557         109400.0              1
# -124.16    40.77     35.0                2141.0       438.0           1053.0      434.0       2.8529         85600.0               1
#            40.79     46.0                3042.0       597.0           1206.0      541.0       2.1135         90600.0               1
#                                                                                                                                   ..
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
data.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
# what is the median income per household?

plt.figure(figsize = (6,6))
plt.plot(data['households'] , data['median_income'] , label = 'households')
plt.xlabel('households')
plt.ylabel('media_income')
plt.title("MEDIAN HOUSEHOLDS INCOME")
plt.show()

# %%
plt.style.use('_mpl-gallery')
plt.figure(figsize = (12,6))
average_income.plot(kind='bar')
plt.plot(data['population'] , data['median_income'] , label = 'population')
plt.xlabel('median income')
plt.ylabel('population')
plt.title("MEDIAN INCOME IN THE WHOLE POPULATION")
plt.show()

# %%
plt.style.use('_mpl-gallery')
plt.figure(figsize = (12,6))
average_income.plot(kind='bar')
plt.plot(data['median_house_value'] , data['median_income'] , label = 'median_house_value')
plt.xlabel('median house value')
plt.ylabel('media_income')
plt.title("MEDIAN HOUSE VALUE VS MEDIAN INCOME")
plt.show()

# %%
plt.style.use('_mpl-gallery')
plt.figure(figsize = (12,6))
average_income.plot(kind = 'bar')
plt.plot(data['housing_median_age'] , data['median_income'] , label = 'population')
plt.xlabel('median_income')
plt.ylabel('housing median age')
plt.title("HOUSING MEDIAN AGE VS MEDIAN INCOME ")
plt.show()

# %%
plt.figure(figsize = (2,4))
average_income.plot(kind='bar')
plt.plot(data['longitude'] , data['latitude'] , label = 'imaginary lines')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title("LONGITUDE VS LATITUDE")
plt.show()

# %%
plt.style.use('_mpl-gallery')
average_income.plot(kind='bar')
plt.figure(figsize = (12,6))
plt.plot(data['housing_median_age'] , data['population'] , )
plt.xlabel('HOUSING MEDIAN AGE')
plt.ylabel('POPULATION')
plt.title("HOUSING MEDIAN AGE IN THE WHOLE POPULATION")
plt.show()
